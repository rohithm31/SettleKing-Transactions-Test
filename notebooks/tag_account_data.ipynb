# %%
import pandas as pd

from flashtext import KeywordProcessor

import re

import os

import warnings

warnings.filterwarnings("ignore")

# %%
account_data_path = r"C:\Users\rohit\settleking_test\data\processed\account_activity.csv"

merchant_data_path = r"C:\Users\rohit\settleking_test\data\processed\merch.csv"

# %%
account_df = pd.read_csv(account_data_path, parse_dates = ["Date"])

merch_df = pd.read_csv(merchant_data_path)

# %%
account_df["Cheque_Number"] = account_df["Cheque_Number"].astype("Int64")

# %%
keyword_processor = KeywordProcessor(case_sensitive = False)

for _,row in merch_df.iterrows():
    keyword = row["alias"]
    category = row["category"]
    keyword_processor.add_keyword(keyword,category)

# %%
def categorize(text):

    matches = keyword_processor.extract_keywords(text)

    if matches:

        matches = list(dict.fromkeys(matches))

        matches += [None] * (3-len(matches))

        return matches[:3]
    
    else:
    
        return ["Miscellaneous","None","None"]

# %%
priority = [
    "Online Purchase",
    "Entertainment",
    "Utility Payment",
    "Direct Deposit",
    "Card Payment",
    "Travel",
    "Investments/Finance",
    "Utility/Insurance",
    "International Transfer",
    "Food",
    "SettleKing",
    "9LLabs",
    "Rewards",
    "P2P Payments",
    "Processing Fee",
    "Fees",
    "Toll",
    "Tax Payment",
    "B2B Payment",
    "Bank Transfer"
]

# %%
def categorize_multi(text):

    match = keyword_processor.extract_keywords(text)

    if match:

        match = list(dict.fromkeys(match))
    
        match_sorted = sorted(

        match,
        key=lambda x: priority.index(x) if x in priority else len(priority)
        )
    
        match_sorted += ["None"] * (3 - len(match_sorted))
    
        return match_sorted[:3]
    
    else:
        
        return ["Miscellaneous","None","None"]

# %%
import random

test_range = [random.randint(0,15) for _ in range(10)]

test_desc = [account_df["Cleaned_Desc"][number] for number in test_range]

# %%
test_desc
# Out:
# ['online transfer from 9llabs llc business checking ref on',
#  'online transfer from 9llabs llc business checking ref on',
#  'online transfer to 9llabs llc ref business checking loan',
#  'state farm ro sfpp s sv',
#  'cybrid 25d568e0',
#  'bell ch academy epay plan c sv',
#  'online transfer to 9llabs llc ref business checking loan',
#  'state farm ro sfpp s sv',
#  'online transfer from 9llabs llc business checking ref on',
#  'business to business ach wsdot good to go good to go a kalvi consulting servi']

# %%
for i in range(0,5):
    
    print(f"Description : {test_desc[i]}\n") 

    print(f"Category : {categorize_multi(test_desc[i])}\n")

    print("--------------------------------------------\n")
# Out:
# Description : online transfer from 9llabs llc business checking ref on
#
# Category : ['9LLabs', 'Bank Transfer', 'None']
#
# --------------------------------------------
#
# Description : online transfer from 9llabs llc business checking ref on
#
# Category : ['9LLabs', 'Bank Transfer', 'None']
#
# --------------------------------------------
#
# Description : online transfer to 9llabs llc ref business checking loan
#
# Category : ['9LLabs', 'Bank Transfer', 'None']
#
# --------------------------------------------
#
# Description : state farm ro sfpp s sv
#
# Category : ['Insurance', 'None', 'None']
#
# --------------------------------------------
#
# Description : cybrid 25d568e0
#
# Category : ['International Transfer', 'None', 'None']
#
# --------------------------------------------

# %%
account_df[["Category_1","Category_2","Category_3"]] = account_df["Cleaned_Desc"].apply(categorize_multi).apply(pd.Series)

# %%
account_df["Category_1"].unique()
# Out:
# array(['Insurance', 'Card Payment', '9LLabs', 'Bank Transfer',
#        'SettleKing', 'Toll', 'Processing Fee', 'Fees', 'Rewards',
#        'International Transfer', 'P2P Payments', 'Utility Payment',
#        'Investments/Finance', 'Tax Payment', 'Miscellaneous',
#        'B2B Payment'], dtype=object)

# %%
account_df.head(n = 5)
# Out:
#         Date   Amount  abs_Amount  Cheque_Number  Transaction_Type  \
# 0 2024-07-24  -217.67      217.67           <NA>                 0
# 1 2024-07-24 -7500.00     7500.00           <NA>                 0
# 2 2024-07-24 -3875.00     3875.00           <NA>                 0
# 3 2024-07-18  -330.00      330.00            127                 0
# 4 2024-07-08 -9975.00     9975.00           <NA>                 0
#
#                                         Cleaned_Desc  \
# 0                            state farm ro sfpp s sv
# 1      online transfer ref to visa signature card on
# 2  online transfer to 9llabs llc ref business che...
# 3                          deposited or cashed check
# 4  online transfer to 9llabs llc ref business che...
#
#                                          Description  Day Month  Year  \
# 0           STATE FARM RO 27 SFPP 15 S 1074398715 SV   24  July  2024
# 1  ONLINE TRANSFER REF #IB0NYCH2M4 TO VISA SIGNAT...   24  July  2024
# 2  ONLINE TRANSFER TO 9LLABS LLC REF #IB0NYCGZRL ...   24  July  2024
# 3                    DEPOSITED OR CASHED CHECK # 127   18  July  2024
# 4  ONLINE TRANSFER TO 9LLABS LLC REF #IB0NSKMG2J ...    8  July  2024
#
#       Category_1     Category_2 Category_3
# 0      Insurance           None       None
# 1   Card Payment  Bank Transfer       None
# 2         9LLabs  Bank Transfer       None
# 3  Bank Transfer           None       None
# 4         9LLabs  Bank Transfer       None

# %%
account_df[account_df["Category_1"] == "Toll"]
# Out:
#          Date  Amount  abs_Amount  Cheque_Number  Transaction_Type  \
# 6  2024-07-05   -1.25        1.25           <NA>                 0
# 42 2024-05-20   -1.25        1.25           <NA>                 0
#
#                                          Cleaned_Desc  \
# 6   business to business ach wsdot good to go good...
# 42  business to business ach wsdot good to go good...
#
#                                           Description  Day Month  Year  \
# 6   BUSINESS TO BUSINESS ACH WSDOT GOOD TO GO GOOD...    5  July  2024
# 42  BUSINESS TO BUSINESS ACH WSDOT GOOD TO GO GOOD...   20   May  2024
#
#    Category_1   Category_2     Category_3
# 6        Toll  B2B Payment  Bank Transfer
# 42       Toll  B2B Payment  Bank Transfer

# %%
account_df.groupby(["Category_1","Category_2"]).count()
# Out:
#                                       Date  Amount  abs_Amount  Cheque_Number  \
# Category_1             Category_2
# 9LLabs                 B2B Payment       1       1           1              0
#                        Bank Transfer     7       7           7              0
# B2B Payment            Bank Transfer     2       2           2              0
# Bank Transfer          None             16      16          16              9
# Card Payment           Bank Transfer     7       7           7              0
# Fees                   Bank Transfer     1       1           1              0
#                        None              8       8           8              0
# Insurance              None              7       7           7              0
# International Transfer None              7       7           7              0
# Investments/Finance    None              4       4           4              0
# Miscellaneous          None              4       4           4              0
# P2P Payments           None              7       7           7              0
# Processing Fee         None              1       1           1              0
# Rewards                None              4       4           4              0
# SettleKing             Bank Transfer     1       1           1              0
#                        None             16      16          16              0
# Tax Payment            None              1       1           1              0
# Toll                   B2B Payment       2       2           2              0
# Utility Payment        None              3       3           3              0
#
#                                       Transaction_Type  Cleaned_Desc  \
# Category_1             Category_2
# 9LLabs                 B2B Payment                   1             1
#                        Bank Transfer                 7             7
# B2B Payment            Bank Transfer                 2             2
# Bank Transfer          None                         16            16
# Card Payment           Bank Transfer                 7             7
# Fees                   Bank Transfer                 1             1
#                        None                          8             8
# Insurance              None                          7             7
# International Transfer None                          7             7
# Investments/Finance    None                          4             4
# Miscellaneous          None                          4             4
# P2P Payments           None                          7             7
# Processing Fee         None                          1             1
# Rewards                None                          4             4
# SettleKing             Bank Transfer                 1             1
#                        None                         16            16
# Tax Payment            None                          1             1
# Toll                   B2B Payment                   2             2
# Utility Payment        None                          3             3
#
#                                       Description  Day  Month  Year  \
# Category_1             Category_2
# 9LLabs                 B2B Payment              1    1      1     1
#                        Bank Transfer            7    7      7     7
# B2B Payment            Bank Transfer            2    2      2     2
# Bank Transfer          None                    16   16     16    16
# Card Payment           Bank Transfer            7    7      7     7
# Fees                   Bank Transfer            1    1      1     1
#                        None                     8    8      8     8
# Insurance              None                     7    7      7     7
# International Transfer None                     7    7      7     7
# Investments/Finance    None                     4    4      4     4
# Miscellaneous          None                     4    4      4     4
# P2P Payments           None                     7    7      7     7
# Processing Fee         None                     1    1      1     1
# Rewards                None                     4    4      4     4
# SettleKing             Bank Transfer            1    1      1     1
#                        None                    16   16     16    16
# Tax Payment            None                     1    1      1     1
# Toll                   B2B Payment              2    2      2     2
# Utility Payment        None                     3    3      3     3
#
#                                       Category_3
# Category_1             Category_2
# 9LLabs                 B2B Payment             1
#                        Bank Transfer           7
# B2B Payment            Bank Transfer           2
# Bank Transfer          None                   16
# Card Payment           Bank Transfer           7
# Fees                   Bank Transfer           1
#                        None                    8
# Insurance              None                    7
# International Transfer None                    7
# Investments/Finance    None                    4
# Miscellaneous          None                    4
# P2P Payments           None                    7
# Processing Fee         None                    1
# Rewards                None                    4
# SettleKing             Bank Transfer           1
#                        None                   16
# Tax Payment            None                    1
# Toll                   B2B Payment             2
# Utility Payment        None                    3

# %%
account_df["round_Amount"] = account_df["Amount"].round(2)

# %%
account_sorted_df = account_df.sort_values(["Category_1","Date","round_Amount"])

# %%
account_sorted_df
# Out:
#          Date    Amount  abs_Amount  Cheque_Number  Transaction_Type  \
# 97 2024-01-24   5000.00     5000.00           <NA>                 1
# 91 2024-02-01  20000.00    20000.00           <NA>                 1
# 76 2024-02-27  -1457.25     1457.25           <NA>                 0
# 48 2024-05-01  25000.00    25000.00           <NA>                 1
# 46 2024-05-08 -20520.00    20520.00           <NA>                 0
# ..        ...       ...         ...            ...               ...
# 42 2024-05-20     -1.25        1.25           <NA>                 0
# 6  2024-07-05     -1.25        1.25           <NA>                 0
# 90 2024-02-01   -578.62      578.62           <NA>                 0
# 57 2024-04-04   -616.97      616.97           <NA>                 0
# 21 2024-06-06   -683.65      683.65           <NA>                 0
#
#                                          Cleaned_Desc  \
# 97           9llabs llc direct dep 93153174682489f sv
# 91  online transfer from 9llabs llc business check...
# 76  business to business ach wa state dol wa st dm...
# 48  online transfer from 9llabs llc ref business c...
# 46  online transfer to 9llabs llc ref business che...
# ..                                                ...
# 42  business to business ach wsdot good to go good...
# 6   business to business ach wsdot good to go good...
# 90                       city of bellevu util bill sv
# 57                       city of bellevu util bill sv
# 21                       city of bellevu util bill sv
#
#                                           Description  Day     Month  Year  \
# 97    9LLABS LLC DIRECT DEP 240124 93153174682489F SV   24   January  2024
# 91  ONLINE TRANSFER FROM 9LLABS LLC BUSINESS CHECK...    1  February  2024
# 76  BUSINESS TO BUSINESS ACH WA STATE DOL WA ST DM...   27  February  2024
# 48  ONLINE TRANSFER FROM 9LLABS LLC REF #IB0N2W75G...    1       May  2024
# 46  ONLINE TRANSFER TO 9LLABS LLC REF #IB0N5DX48M ...    8       May  2024
# ..                                                ...  ...       ...   ...
# 42  BUSINESS TO BUSINESS ACH WSDOT GOOD TO GO GOOD...   20       May  2024
# 6   BUSINESS TO BUSINESS ACH WSDOT GOOD TO GO GOOD...    5      July  2024
# 90       CITY OF BELLEVU UTIL BILL 240201 18688005 SV    1  February  2024
# 57       CITY OF BELLEVU UTIL BILL 240404 18688005 SV    4     April  2024
# 21       CITY OF BELLEVU UTIL BILL 240606 18688005 SV    6      June  2024
#
#          Category_1     Category_2     Category_3  round_Amount
# 97           9LLabs  Bank Transfer           None       5000.00
# 91           9LLabs  Bank Transfer           None      20000.00
# 76           9LLabs    B2B Payment  Bank Transfer      -1457.25
# 48           9LLabs  Bank Transfer           None      25000.00
# 46           9LLabs  Bank Transfer           None     -20520.00
# ..              ...            ...            ...           ...
# 42             Toll    B2B Payment  Bank Transfer         -1.25
# 6              Toll    B2B Payment  Bank Transfer         -1.25
# 90  Utility Payment           None           None       -578.62
# 57  Utility Payment           None           None       -616.97
# 21  Utility Payment           None           None       -683.65
#
# [99 rows x 14 columns]

# %%
account_sorted_df["Previous_Day"] = account_sorted_df.groupby("Category_1")["Date"].shift(1)

# %%
account_sorted_df["Gap_Days"] = (account_sorted_df["Date"] - account_sorted_df["Previous_Day"]).dt.days

# %%
account_sorted_df["Rec_30"] = account_sorted_df["Gap_Days"].between(20,40)

account_sorted_df["Rec_60"] = account_sorted_df["Gap_Days"].between(50,70)

account_sorted_df["Rec_90"] = account_sorted_df["Gap_Days"].between(85,95)

# %%
account_sorted_df["RecurringStreak_30"] = account_sorted_df.groupby("Category_1")["Rec_30"].cumsum()

account_sorted_df["RecurringStreak_60"] = account_sorted_df.groupby("Category_1")["Rec_60"].cumsum()

account_sorted_df["RecurringStreak_90"] = account_sorted_df.groupby("Category_1")["Rec_90"].cumsum()

# %%
account_sorted_df["Is_Recurring_30"] = account_sorted_df["RecurringStreak_30"].map(lambda x: 1 if x >= 2 else 0)

account_sorted_df["Is_Recurring_60"] = account_sorted_df["RecurringStreak_60"].map(lambda x: 1 if x >= 2 else 0)

account_sorted_df["Is_Recurring_90"] = account_sorted_df["RecurringStreak_90"].map(lambda x: 1 if x >= 2 else 0)

# %%
account_sorted_df
# Out:
#          Date    Amount  abs_Amount  Cheque_Number  Transaction_Type  \
# 97 2024-01-24   5000.00     5000.00           <NA>                 1
# 91 2024-02-01  20000.00    20000.00           <NA>                 1
# 76 2024-02-27  -1457.25     1457.25           <NA>                 0
# 48 2024-05-01  25000.00    25000.00           <NA>                 1
# 46 2024-05-08 -20520.00    20520.00           <NA>                 0
# ..        ...       ...         ...            ...               ...
# 42 2024-05-20     -1.25        1.25           <NA>                 0
# 6  2024-07-05     -1.25        1.25           <NA>                 0
# 90 2024-02-01   -578.62      578.62           <NA>                 0
# 57 2024-04-04   -616.97      616.97           <NA>                 0
# 21 2024-06-06   -683.65      683.65           <NA>                 0
#
#                                          Cleaned_Desc  \
# 97           9llabs llc direct dep 93153174682489f sv
# 91  online transfer from 9llabs llc business check...
# 76  business to business ach wa state dol wa st dm...
# 48  online transfer from 9llabs llc ref business c...
# 46  online transfer to 9llabs llc ref business che...
# ..                                                ...
# 42  business to business ach wsdot good to go good...
# 6   business to business ach wsdot good to go good...
# 90                       city of bellevu util bill sv
# 57                       city of bellevu util bill sv
# 21                       city of bellevu util bill sv
#
#                                           Description  Day     Month  Year  \
# 97    9LLABS LLC DIRECT DEP 240124 93153174682489F SV   24   January  2024
# 91  ONLINE TRANSFER FROM 9LLABS LLC BUSINESS CHECK...    1  February  2024
# 76  BUSINESS TO BUSINESS ACH WA STATE DOL WA ST DM...   27  February  2024
# 48  ONLINE TRANSFER FROM 9LLABS LLC REF #IB0N2W75G...    1       May  2024
# 46  ONLINE TRANSFER TO 9LLABS LLC REF #IB0N5DX48M ...    8       May  2024
# ..                                                ...  ...       ...   ...
# 42  BUSINESS TO BUSINESS ACH WSDOT GOOD TO GO GOOD...   20       May  2024
# 6   BUSINESS TO BUSINESS ACH WSDOT GOOD TO GO GOOD...    5      July  2024
# 90       CITY OF BELLEVU UTIL BILL 240201 18688005 SV    1  February  2024
# 57       CITY OF BELLEVU UTIL BILL 240404 18688005 SV    4     April  2024
# 21       CITY OF BELLEVU UTIL BILL 240606 18688005 SV    6      June  2024
#
#     ... Gap_Days Rec_30 Rec_60  Rec_90 RecurringStreak_30  RecurringStreak_60  \
# 97  ...      NaN  False  False   False                  0                   0
# 91  ...      8.0  False  False   False                  0                   0
# 76  ...     26.0   True  False   False                  1                   0
# 48  ...     64.0  False   True   False                  1                   1
# 46  ...      7.0  False  False   False                  1                   1
# ..  ...      ...    ...    ...     ...                ...                 ...
# 42  ...      NaN  False  False   False                  0                   0
# 6   ...     46.0  False  False   False                  0                   0
# 90  ...      NaN  False  False   False                  0                   0
# 57  ...     63.0  False   True   False                  0                   1
# 21  ...     63.0  False   True   False                  0                   2
#
#     RecurringStreak_90  Is_Recurring_30  Is_Recurring_60  Is_Recurring_90
# 97                   0                0                0                0
# 91                   0                0                0                0
# 76                   0                0                0                0
# 48                   0                0                0                0
# 46                   0                0                0                0
# ..                 ...              ...              ...              ...
# 42                   0                0                0                0
# 6                    0                0                0                0
# 90                   0                0                0                0
# 57                   0                0                0                0
# 21                   0                0                1                0
#
# [99 rows x 25 columns]

# %%
account_sorted_df.groupby("Is_Recurring_30")["Is_Recurring_30"].count()
# Out:
# Is_Recurring_30
# 0    78
# 1    21
# Name: Is_Recurring_30, dtype: int64

# %%
account_sorted_df.groupby("Is_Recurring_60")["Is_Recurring_60"].count()
# Out:
# Is_Recurring_60
# 0    94
# 1     5
# Name: Is_Recurring_60, dtype: int64

# %%
account_sorted_df[account_sorted_df["Is_Recurring_60"] == 1]
# Out:
#          Date    Amount  abs_Amount  Cheque_Number  Transaction_Type  \
# 10 2024-07-01  12500.00    12500.00           <NA>                 1
# 4  2024-07-08  -9975.00     9975.00           <NA>                 0
# 2  2024-07-24  -3875.00     3875.00           <NA>                 0
# 12 2024-06-21    250.00      250.00           <NA>                 1
# 21 2024-06-06   -683.65      683.65           <NA>                 0
#
#                                          Cleaned_Desc  \
# 10  online transfer from 9llabs llc business check...
# 4   online transfer to 9llabs llc ref business che...
# 2   online transfer to 9llabs llc ref business che...
# 12                                wells fargo rewards
# 21                       city of bellevu util bill sv
#
#                                           Description  Day Month  Year  ...  \
# 10  ONLINE TRANSFER FROM 9LLABS LLC BUSINESS CHECK...    1  July  2024  ...
# 4   ONLINE TRANSFER TO 9LLABS LLC REF #IB0NSKMG2J ...    8  July  2024  ...
# 2   ONLINE TRANSFER TO 9LLABS LLC REF #IB0NYCGZRL ...   24  July  2024  ...
# 12                                WELLS FARGO REWARDS   21  June  2024  ...
# 21       CITY OF BELLEVU UTIL BILL 240606 18688005 SV    6  June  2024  ...
#
#    Gap_Days Rec_30 Rec_60  Rec_90 RecurringStreak_30  RecurringStreak_60  \
# 10     54.0  False   True   False                  1                   2
# 4       7.0  False  False   False                  1                   2
# 2      16.0  False  False   False                  1                   2
# 12     60.0  False   True   False                  1                   2
# 21     63.0  False   True   False                  0                   2
#
#     RecurringStreak_90  Is_Recurring_30  Is_Recurring_60  Is_Recurring_90
# 10                   0                0                1                0
# 4                    0                0                1                0
# 2                    0                0                1                0
# 12                   0                0                1                0
# 21                   0                0                1                0
#
# [5 rows x 25 columns]

# %%
account_sorted_df.to_csv("../data/processed/account_sorted.csv", index = False, encoding = "utf-8", date_format = "%Y-%m-%d")
